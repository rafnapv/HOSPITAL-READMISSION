# %% [markdown]
# PATIENT READMISSION

# %%
import pandas as pd

# %%
a=pd.read_csv('patient_readmission.csv')
a
# Out:
#            date  num_patients_admitted  avg_length_of_stay  \
# 0    2020-01-01                     96            6.429705
# 1    2020-01-02                    107            5.430686
# 2    2020-01-03                     88            4.081344
# 3    2020-01-04                    103            5.542255
# 4    2020-01-05                    111            3.284411
# ..          ...                    ...                 ...
# 995  2022-09-22                     83            4.906994
# 996  2022-09-23                    120            6.427174
# 997  2022-09-24                    105            4.450239
# 998  2022-09-25                    103            3.000000
# 999  2022-09-26                    104            3.613301
#
#      avg_lab_result_score  hospital_resource_utilization  readmission_rate
# 0               72.699496                       0.310710          0.111707
# 1               88.122348                       0.455792          0.113145
# ...

# %%
a.shape
# Out:
# (1000, 6)

# %%
a.head()
# Out:
#          date  num_patients_admitted  avg_length_of_stay  \
# 0  2020-01-01                     96            6.429705
# 1  2020-01-02                    107            5.430686
# 2  2020-01-03                     88            4.081344
# 3  2020-01-04                    103            5.542255
# 4  2020-01-05                    111            3.284411
#
#    avg_lab_result_score  hospital_resource_utilization  readmission_rate
# 0             72.699496                       0.310710          0.111707
# 1             88.122348                       0.455792          0.113145
# 2             56.300101                       0.339738          0.050000
# 3             59.820961                       0.474732          0.056116
# 4             97.572241                       0.441357          0.154602

# %%
a.tail()
# Out:
#            date  num_patients_admitted  avg_length_of_stay  \
# 995  2022-09-22                     83            4.906994
# 996  2022-09-23                    120            6.427174
# 997  2022-09-24                    105            4.450239
# 998  2022-09-25                    103            3.000000
# 999  2022-09-26                    104            3.613301
#
#      avg_lab_result_score  hospital_resource_utilization  readmission_rate
# 995             65.169277                       0.200000          0.087708
# 996             89.094546                       0.672097          0.159806
# 997             88.292932                       0.424381          0.138062
# 998             84.582783                       0.432793          0.113638
# 999             98.281949                       0.424518          0.137377

# %%
a.describe
# Out:
# <bound method NDFrame.describe of            date  num_patients_admitted  avg_length_of_stay  \
# 0    2020-01-01                     96            6.429705
# 1    2020-01-02                    107            5.430686
# 2    2020-01-03                     88            4.081344
# 3    2020-01-04                    103            5.542255
# 4    2020-01-05                    111            3.284411
# ..          ...                    ...                 ...
# 995  2022-09-22                     83            4.906994
# 996  2022-09-23                    120            6.427174
# 997  2022-09-24                    105            4.450239
# 998  2022-09-25                    103            3.000000
# 999  2022-09-26                    104            3.613301
#
#      avg_lab_result_score  hospital_resource_utilization  readmission_rate
# 0               72.699496                       0.310710          0.111707
# ...

# %%
a.isnull().sum()
# Out:
# date                             0
# num_patients_admitted            0
# avg_length_of_stay               0
# avg_lab_result_score             0
# hospital_resource_utilization    0
# readmission_rate                 0
# dtype: int64

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   date                           1000 non-null   object
#  1   num_patients_admitted          1000 non-null   int64
#  2   avg_length_of_stay             1000 non-null   float64
#  3   avg_lab_result_score           1000 non-null   float64
#  4   hospital_resource_utilization  1000 non-null   float64
#  5   readmission_rate               1000 non-null   float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 47.0+ KB

# %% [markdown]
# LABEL ENCODING

# %%
from sklearn import tree
from sklearn.preprocessing import LabelEncoder

# %%
h=LabelEncoder()
i=h.fit_transform(a['date'])
a['date']=i
a
# Out:
#      date  num_patients_admitted  avg_length_of_stay  avg_lab_result_score  \
# 0       0                     96            6.429705             72.699496
# 1       1                    107            5.430686             88.122348
# 2       2                     88            4.081344             56.300101
# 3       3                    103            5.542255             59.820961
# 4       4                    111            3.284411             97.572241
# ..    ...                    ...                 ...                   ...
# 995   995                     83            4.906994             65.169277
# 996   996                    120            6.427174             89.094546
# 997   997                    105            4.450239             88.292932
# 998   998                    103            3.000000             84.582783
# 999   999                    104            3.613301             98.281949
#
#      hospital_resource_utilization  readmission_rate
# ...

# %% [markdown]
# CORE RELATION

# %%
a.corr()
# Out:
#                                    date  num_patients_admitted  \
# date                           1.000000               0.014220
# num_patients_admitted          0.014220               1.000000
# avg_length_of_stay             0.009472               0.045987
# avg_lab_result_score           0.013426               0.005488
# hospital_resource_utilization  0.019208               0.903718
# readmission_rate               0.014927               0.006756
#
#                                avg_length_of_stay  avg_lab_result_score  \
# date                                     0.009472              0.013426
# num_patients_admitted                    0.045987              0.005488
# avg_length_of_stay                       1.000000              0.021588
# avg_lab_result_score                     0.021588              1.000000
# hospital_resource_utilization            0.050400              0.008835
# readmission_rate                         0.156901              0.959581
#
# ...

# %% [markdown]
# TRAIN TEST SPLIT

# %%
from sklearn.model_selection import train_test_split

# %%
x=a.drop('readmission_rate',axis='columns')
x
# Out:
#      date  num_patients_admitted  avg_length_of_stay  avg_lab_result_score  \
# 0       0                     96            6.429705             72.699496
# 1       1                    107            5.430686             88.122348
# 2       2                     88            4.081344             56.300101
# 3       3                    103            5.542255             59.820961
# 4       4                    111            3.284411             97.572241
# ..    ...                    ...                 ...                   ...
# 995   995                     83            4.906994             65.169277
# 996   996                    120            6.427174             89.094546
# 997   997                    105            4.450239             88.292932
# 998   998                    103            3.000000             84.582783
# 999   999                    104            3.613301             98.281949
#
#      hospital_resource_utilization
# ...

# %%
y=a.readmission_rate
y
# Out:
# 0      0.111707
# 1      0.113145
# 2      0.050000
# 3      0.056116
# 4      0.154602
#          ...
# 995    0.087708
# 996    0.159806
# 997    0.138062
# 998    0.113638
# 999    0.137377
# Name: readmission_rate, Length: 1000, dtype: float64

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=60)
xtrain,xtest,ytrain,ytest
# Out:
# (     date  num_patients_admitted  avg_length_of_stay  avg_lab_result_score  \
#  679   679                    114            5.820897             72.101671
#  381   381                    110            4.321865             52.012900
#  831   831                     86            3.577478             51.200252
#  471   471                     83            5.375300             52.006943
#  349   349                    101            4.463832             77.322927
#  ..    ...                    ...                 ...                   ...
#  399   399                    113            6.185938             96.519921
#  394   394                     89            7.129405             91.618177
#  582   582                    130            6.526492             65.745922
#  65     65                     92            7.397971             69.893285
#  205   205                     99            4.236555             53.361709
#
#       hospital_resource_utilization
# ...

# %% [markdown]
# LINEAR REGRESSION

# %%
from sklearn import linear_model
import warnings
warnings.filterwarnings('ignore')

# %%
model1=linear_model.LinearRegression()
model1.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
model1.predict(xtest)
# Out:
# array([0.06349725, 0.09266894, 0.10091217, 0.16622545, 0.09332935,
#        0.17117165, 0.04275987, 0.05409872, 0.17510854, 0.13655979,
#        0.1299004 , 0.05971673, 0.1460743 , 0.08162085, 0.09906908,
#        0.12279219, 0.06121303, 0.09212239, 0.05718468, 0.05357346,
#        0.10836901, 0.05986357, 0.08529673, 0.07117296, 0.11254826,
#        0.16180548, 0.04144026, 0.07361645, 0.04883792, 0.0787507 ,
#        0.13663458, 0.03717482, 0.03970606, 0.06576125, 0.14204693,
#        0.11210972, 0.04471017, 0.05994552, 0.15562125, 0.12325513,
#        0.12484346, 0.09078723, 0.16653427, 0.09890143, 0.05852315,
#        0.12935378, 0.15007919, 0.163564  , 0.09646592, 0.10076364,
#        0.05984033, 0.12544815, 0.08357369, 0.1206923 , 0.04756172,
#        0.16185624, 0.15732867, 0.03592668, 0.05570426, 0.04677893,
#        0.08272287, 0.091284  , 0.14692345, 0.0948411 , 0.12191971,
#        0.02930009, 0.04924852, 0.15716705, 0.11406691, 0.13244044,
# ...

# %%
model1.score(xtest,ytest)
# Out:
# 0.9438479305730951

# %% [markdown]
# SVR

# %%
from sklearn.svm import SVR

# %%
model2=SVR()
model2.fit(xtrain,ytrain)
# Out:
# SVR()

# %% [markdown]
# KERNALS(LINEAR,POLY,RBF)

# %% [markdown]
# LINEAR

# %%
model3=SVR(kernel='linear')
model3.fit(xtrain,ytrain)
# Out:
# SVR(kernel='linear')

# %%
model3.predict(xtest)
# Out:
# array([0.12068981, 0.12068981, 0.12068981, 0.12068981, 0.12068981,
#        0.12068981, 0.12068981, 0.12068981, 0.12068981, 0.12068981,
#        0.12068981, 0.12068981, 0.12068981, 0.12068981, 0.12068981,
#        0.12068981, 0.12068981, 0.12068981, 0.12068981, 0.12068981,
#        0.12068981, 0.12068981, 0.12068981, 0.12068981, 0.12068981,
#        0.12068981, 0.12068981, 0.12068981, 0.12068981, 0.12068981,
#        0.12068981, 0.12068981, 0.12068981, 0.12068981, 0.12068981,
#        0.12068981, 0.12068981, 0.12068981, 0.12068981, 0.12068981,
#        0.12068981, 0.12068981, 0.12068981, 0.12068981, 0.12068981,
#        0.12068981, 0.12068981, 0.12068981, 0.12068981, 0.12068981,
#        0.12068981, 0.12068981, 0.12068981, 0.12068981, 0.12068981,
#        0.12068981, 0.12068981, 0.12068981, 0.12068981, 0.12068981,
#        0.12068981, 0.12068981, 0.12068981, 0.12068981, 0.12068981,
#        0.12068981, 0.12068981, 0.12068981, 0.12068981, 0.12068981,
# ...

# %%
model3.score(xtest,ytest)
# Out:
# -0.22144987922642145

# %% [markdown]
# POLY

# %%
model4=SVR(kernel='poly')
model4.fit(xtrain,ytrain)
# Out:
# SVR(kernel='poly')

# %%
model4.predict(xtest)
# Out:
# array([0.12068981, 0.12068981, 0.12068981, 0.12068981, 0.12068981,
#        0.12068981, 0.12068981, 0.12068981, 0.12068981, 0.12068981,
#        0.12068981, 0.12068981, 0.12068981, 0.12068981, 0.12068981,
#        0.12068981, 0.12068981, 0.12068981, 0.12068981, 0.12068981,
#        0.12068981, 0.12068981, 0.12068981, 0.12068981, 0.12068981,
#        0.12068981, 0.12068981, 0.12068981, 0.12068981, 0.12068981,
#        0.12068981, 0.12068981, 0.12068981, 0.12068981, 0.12068981,
#        0.12068981, 0.12068981, 0.12068981, 0.12068981, 0.12068981,
#        0.12068981, 0.12068981, 0.12068981, 0.12068981, 0.12068981,
#        0.12068981, 0.12068981, 0.12068981, 0.12068981, 0.12068981,
#        0.12068981, 0.12068981, 0.12068981, 0.12068981, 0.12068981,
#        0.12068981, 0.12068981, 0.12068981, 0.12068981, 0.12068981,
#        0.12068981, 0.12068981, 0.12068981, 0.12068981, 0.12068981,
#        0.12068981, 0.12068981, 0.12068981, 0.12068981, 0.12068981,
# ...

# %%
model4.score(xtest,ytest)
# Out:
# -0.22144987922642145

# %% [markdown]
# RBF

# %%
model5=SVR(kernel='rbf')
model5.fit(xtrain,ytrain)
# Out:
# SVR()

# %%
model5.predict(xtest)
# Out:
# array([0.12068981, 0.12068981, 0.12068981, 0.12068981, 0.12068981,
#        0.12068981, 0.12068981, 0.12068981, 0.12068981, 0.12068981,
#        0.12068981, 0.12068981, 0.12068981, 0.12068981, 0.12068981,
#        0.12068981, 0.12068981, 0.12068981, 0.12068981, 0.12068981,
#        0.12068981, 0.12068981, 0.12068981, 0.12068981, 0.12068981,
#        0.12068981, 0.12068981, 0.12068981, 0.12068981, 0.12068981,
#        0.12068981, 0.12068981, 0.12068981, 0.12068981, 0.12068981,
#        0.12068981, 0.12068981, 0.12068981, 0.12068981, 0.12068981,
#        0.12068981, 0.12068981, 0.12068981, 0.12068981, 0.12068981,
#        0.12068981, 0.12068981, 0.12068981, 0.12068981, 0.12068981,
#        0.12068981, 0.12068981, 0.12068981, 0.12068981, 0.12068981,
#        0.12068981, 0.12068981, 0.12068981, 0.12068981, 0.12068981,
#        0.12068981, 0.12068981, 0.12068981, 0.12068981, 0.12068981,
#        0.12068981, 0.12068981, 0.12068981, 0.12068981, 0.12068981,
# ...

# %%
model5.score(xtest,ytest)
# Out:
# -0.22144987922642145

# %% [markdown]
# DECISION TREE REGRESSOR

# %%
from sklearn import tree

# %%
model6=tree.DecisionTreeRegressor()
model6.fit(xtrain,ytrain)
# Out:
# DecisionTreeRegressor()

# %%
model6.predict(xtest)
# Out:
# array([0.07277369, 0.08449142, 0.10705463, 0.17132269, 0.08661213,
#        0.16000863, 0.05      , 0.05      , 0.18422341, 0.13235662,
#        0.14105465, 0.05308669, 0.14648841, 0.09066073, 0.10459005,
#        0.12047508, 0.05      , 0.08249293, 0.05      , 0.05      ,
#        0.10103658, 0.06816348, 0.08398623, 0.07374037, 0.11725483,
#        0.16355707, 0.05      , 0.05557514, 0.05      , 0.08193243,
#        0.13319253, 0.05      , 0.05078966, 0.05729438, 0.13378862,
#        0.10202856, 0.05078966, 0.05      , 0.15758869, 0.14079498,
#        0.13032893, 0.07998045, 0.16662382, 0.10599654, 0.05      ,
#        0.14020198, 0.15825646, 0.16537182, 0.11571327, 0.10100422,
#        0.05477171, 0.11834781, 0.08203657, 0.12950094, 0.05      ,
#        0.166501  , 0.14715001, 0.05      , 0.05      , 0.05      ,
#        0.0599594 , 0.08249293, 0.15595966, 0.08238733, 0.12223333,
#        0.05837292, 0.05      , 0.15259198, 0.12064322, 0.13319253,
# ...

# %%
model6.score(xtest,ytest)
# Out:
# 0.8986789667028052

# %% [markdown]
# RANDOM FOREST REGRESSOR

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model7=RandomForestRegressor(n_estimators=65)
model7.fit(xtrain,ytrain)
# Out:
# RandomForestRegressor(n_estimators=65)

# %%
model7.predict(xtest)
# Out:
# array([0.06591764, 0.08394378, 0.1022342 , 0.16819095, 0.089005  ,
#        0.16950627, 0.0511489 , 0.05696982, 0.17979557, 0.13642213,
#        0.12956299, 0.05464359, 0.14579493, 0.07693329, 0.10395939,
#        0.12476089, 0.05650727, 0.08307385, 0.05532675, 0.05168144,
#        0.10611591, 0.05612223, 0.07837605, 0.07111165, 0.11552959,
#        0.16553515, 0.05      , 0.06880704, 0.05109468, 0.07203478,
#        0.13672727, 0.05065029, 0.05062517, 0.05793764, 0.1365924 ,
#        0.10796734, 0.05100039, 0.05210578, 0.15527067, 0.12811679,
#        0.12795427, 0.0867717 , 0.173395  , 0.09780393, 0.0585138 ,
#        0.13706474, 0.15563938, 0.1643104 , 0.0939219 , 0.10298631,
#        0.0551669 , 0.11795638, 0.07291547, 0.1210748 , 0.05103366,
#        0.1625189 , 0.15722549, 0.0527747 , 0.05309318, 0.05106011,
#        0.07422678, 0.09201859, 0.15385404, 0.0876835 , 0.11951593,
#        0.05323901, 0.050557  , 0.1600272 , 0.12068045, 0.13580812,
# ...

# %%
model7.score(xtest,ytest)
# Out:
# 0.9454489239808013

# %% [markdown]
# KNEIGHBORS REGRESSOR

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
model8=KNeighborsRegressor(n_neighbors=4)
model8.fit(xtrain,ytrain)
# Out:
# KNeighborsRegressor(n_neighbors=4)

# %%
model8.predict(xtest)
# Out:
# array([0.05474107, 0.07576034, 0.09578394, 0.14395303, 0.08947508,
#        0.17314891, 0.05460133, 0.05375826, 0.14270778, 0.12036575,
#        0.11799755, 0.07034797, 0.13108977, 0.08809957, 0.10785569,
#        0.12301834, 0.06367455, 0.09864348, 0.05      , 0.06519731,
#        0.10766134, 0.06033664, 0.10683207, 0.0545219 , 0.1178179 ,
#        0.16093786, 0.06121198, 0.06430425, 0.05998293, 0.07460131,
#        0.1513291 , 0.06061279, 0.05119293, 0.06023116, 0.1472583 ,
#        0.10621814, 0.05454087, 0.07125532, 0.1541575 , 0.13185638,
#        0.14565431, 0.1044019 , 0.14348136, 0.09368352, 0.06425412,
#        0.11972161, 0.14081997, 0.15521429, 0.09212596, 0.09186784,
#        0.06366264, 0.11845276, 0.09855067, 0.11199385, 0.07227651,
#        0.13916202, 0.15033745, 0.05790118, 0.07283455, 0.05901683,
#        0.0776914 , 0.1085776 , 0.11700947, 0.09271762, 0.11722742,
#        0.05561257, 0.06773659, 0.14472038, 0.09452547, 0.12757149,
# ...

# %%
model8.score(xtest,ytest)
# Out:
# 0.8454553283386426

# %% [markdown]
# VISUALIZATION

# %% [markdown]
# Time series: Number of patients over time

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(14,5))
sns.lineplot(data=a, x="date", y="num_patients_admitted", color="blue")
plt.title("Number of Patients Admitted Over Time", fontsize=14)
plt.xlabel("Date")
plt.ylabel("Patients Admitted")
plt.show()

# %% [markdown]
# Time series: Average length of stay

# %%
plt.figure(figsize=(14,5))
sns.lineplot(data=a, x="date", y="avg_length_of_stay", color="green")
plt.title("Average Length of Stay Over Time", fontsize=14)
plt.xlabel("Date")
plt.ylabel("Average Length of Stay (days)")
plt.show()

# %% [markdown]
# Correlation heatmap

# %%
plt.figure(figsize=(8,6))
corr = a.drop(columns=['date']).corr()
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Between Hospital Metrics", fontsize=14)
plt.show()

# %% [markdown]
# Pairplot to see relationships between variables

# %%
sns.pairplot(a.drop(columns=['date']), diag_kind="kde")
plt.suptitle("Relationships Between Variables", y=1.02)
plt.show()

# %% [markdown]
# Distribution of readmission rate

# %%
plt.figure(figsize=(8,5))
sns.histplot(a["readmission_rate"], bins=30, kde=True, color="purple")
plt.title("Distribution of Readmission Rate", fontsize=14)
plt.xlabel("Readmission Rate")
plt.ylabel("Frequency")
plt.show()
